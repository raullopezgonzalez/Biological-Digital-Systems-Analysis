# %%
import matplotlib.pyplot as plt
from scipy import *
from scipy import integrate
from scipy.integrate import ode
import numpy as np

fig = plt.figure(num=1)
ax=fig.add_subplot(111)



def vf(t,x):
  dx=np.zeros(2)

  dx[0]=1
  dx[1]= (x[0]*x[1] - x[0]*(1 - x[0]*x[0]))/(1-x[0]*x[0])
  return dx

##Solution curves
t0=0; tEnd=10; dt=0.01;
r = ode(vf).set_integrator('vode', method='bdf',max_step=dt)

##Initial conditions for ecah line with its color
ic=[[2,2]]
color=['r','b']
listY = []

for k in range(len(ic)):
    Y=[];T=[];S=[];
    r.set_initial_value(ic[k], t0).set_f_params()
    while r.successful() and r.t +dt < tEnd:
        r.integrate(r.t+dt)
        Y.append(r.y)

    S=np.array(np.real(Y))
    ax.plot(S[:,0],S[:,1], color = color[k], lw = 5.25)
    
    for elem in S[:,1]:
        listY.append(elem)

##Vector field with its linespace(interval)
X,Y = np.meshgrid( np.linspace(-5,5,25),np.linspace(-5,5,25) )

V = (X*Y -X*(1-X*X))/(1-X*X)


##Normalize arrows not to have long arrows similar
U = 1
N = np.sqrt(U**2+V**2)  
U2, V2 = U/N, V/N
ax.quiver( X,Y,U2, V2)

y_exact = (5.196152422706631/np.sqrt(S[:,0]*S[:,0]-1)) - (S[:,0]*S[:,0]/3) + (1/3)
plt.plot(S[:,0], y_exact, color = "b")




##Limits of the graph
plt.xlim([-5,5])
plt.ylim([-5,5])
plt.xlabel(r"$x$")
plt.ylabel(r"$y$")
plt.show()

# %%
import math as m
def k(x,y):
    k = (y + (x*x/3) - (1/3))*np.sqrt(x*x-1)
    return k
k(2,2)
# Out:
# 5.196152422706631

# %%
y_diff = np.abs(y_exact - listY)
plt.semilogy(S[:,0], y_diff)
plt.ylabel("Error")
plt.xlabel("x")
plt.title("Error in numerical integration");
# Note the logarithmic scale on the y-axis.

# %%
import matplotlib.pyplot as plt
from scipy import *
from scipy import integrate
from scipy.integrate import ode
import numpy as np

fig = plt.figure(num=1)
ax=fig.add_subplot(111)



def vf(t,x):
  dx=np.zeros(2)

  dx[0]=1
  dx[1]= (x[0]*x[1] - x[0]*(1 - x[0]*x[0]))/(1-x[0]*x[0])
  return dx

##Solution curves
t0=0; tEnd=10; dt=0.01;
r = ode(vf).set_integrator('vode', method='bdf',max_step=dt)

##Initial conditions for ecah line with its color
ic=[[-2,-2]]
color=['r']
listY = []

for k in range(len(ic)):
    Y=[];T=[];S=[];
    r.set_initial_value(ic[k], t0).set_f_params()
    while r.successful() and r.t +dt < tEnd:
        r.integrate(r.t+dt)
        Y.append(r.y)

    S=np.array(np.real(Y))
    ax.plot(S[:,0],S[:,1], color = color[k], lw = 5.25)
    
    for elem in S[:,1]:
        listY.append(elem)

##Vector field with its linespace(interval)
X,Y = np.meshgrid( np.linspace(-5,5,25),np.linspace(-5,5,25) )

V = (X*Y -X*(1-X*X))/(1-X*X)


##Normalize arrows not to have long arrows similar
U = 1
N = np.sqrt(U**2+V**2)  
U2, V2 = U/N, V/N
ax.quiver( X,Y,U2, V2)

y_exact2 = (-1.7320508075688772/np.sqrt(S[:,0]*S[:,0]-1)) - (S[:,0]*S[:,0]/3) + (1/3)
plt.plot(S[:,0], y_exact2, color = "b")




##Limits of the graph
plt.xlim([-5,5])
plt.ylim([-5,5])
plt.xlabel(r"$x$")
plt.ylabel(r"$y$")
plt.show()
# Out:
# C:\Users\riul0\Anaconda3\lib\site-packages\scipy\integrate\_ode.py:1009: UserWarning: vode: Excess work done on this call. (Perhaps wrong MF.)
#   self.messages.get(istate, unexpected_istate_msg)))

# %%
y_diff2 = np.abs(y_exact2 - listY)
plt.semilogy(S[:,0], y_diff2)
plt.ylabel("Error")
plt.xlabel("x")
plt.title("Error in numerical integration");
# Note the logarithmic scale on the y-axis.
